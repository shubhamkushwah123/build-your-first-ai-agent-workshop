# %% [markdown]
# # 1. Initializing LLM

# %%
from langchain_openai import ChatOpenAI

llm = ChatOpenAI(
    base_url="https://router.huggingface.co/v1",
    api_key="Enter your API key",
    model="meta-llama/Llama-3.1-8B-Instruct:cerebras",
    max_tokens=500
)

# %%
system_message = """You are a helpful travel planner."""
human_message = "Plan a travel to {destination} for {number_of_days}"

# %% [markdown]
# # 2. Define Agent Templates with variables

# %%
from langchain_core.prompts import ChatPromptTemplate, SystemMessagePromptTemplate, HumanMessagePromptTemplate
template = ChatPromptTemplate.from_messages([
    SystemMessagePromptTemplate.from_template(system_message),
    HumanMessagePromptTemplate.from_template(f"{human_message}")
])

# %% [markdown]
# # 3. Take Input from the User.

# %%
print("I am your travel planner, I need few details before I can plan an itenary for you")

destination = input("What would be your destination?")

number_of_days = input(f"How long you are planning to stay in {destination}")
# Out:
# I am your travel planner, I need few details before I can plan an itenary for you
# What would be your destination? Paris
# How long you are planning to stay in Paris 2

# %% [markdown]
# # 4. Format template variables

# %%
message = template.format(destination=destination,number_of_days=number_of_days)

# %%
response = llm.invoke(message)
print(response.content)
# Out:
# Bonjour!  I'd be delighted to help plan a romantic getaway to the City of Light for you and your partner. Here's a 7-day itinerary that includes a mix of popular attractions, cultural experiences, and cozy accommodations.
#
# **Day 1: Arrival and Exploring Montmartre**
#
# * Arrive at Charles de Gaulle Airport and take a taxi or train (RER B) to your hotel in the Latin Quarter or Le Marais
# * Visit the historic Sacré-Cœur Basilica and explore the charming streets of Montmartre
# * Enjoy dinner at a traditional French bistro, such as Le Comptoir du Relais
#
# **Day 2: Iconic Landmarks**
#
# * Visit the Eiffel Tower (buy tickets in advance to avoid long lines) and enjoy stunning views of the city
# * Stroll along the Seine River to the Île de la Cité and visit the famous Notre-Dame Cathedral
# * Visit the Musée d'Orsay, which houses an impressive collection of Impressionist and Post-Impressionist art
#
# **Day 3: Museums and History**
#
# * Visit the world-renowned Louvre Museum, home to the Mona Lisa and other famous artworks
# * Explore the historic Saint-Germain-des-Prés neighborhood, known for its upscale boutiques, cafes, and art galleries
# * Visit the Musée Rodin, dedicated to the life and works of French sculptor Auguste Rodin
#
# **Day 4: Palace and Gardens**
#
# * Visit the stunning Palace of Versailles, including its opulent State Apartments and Hall of Mirrors
# * Explore the beautiful Gardens of Versailles and admire the fountains and statues
# * Return to Paris and enjoy a Seine River cruise at sunset
#
# **Day 5: Markets and Food**
#
# * Visit the historic Marché aux Puces de Saint-Ouen (flea market) or the more upscale Galeries Lafayette department store
# * Sample the finest French cuisine at Le Grand Vefour or try a classic baguette at Boulangerie Gérard Mulot
# * Explore the trendy street food scene at the Marché d'Aligre or the Île de la Cité market
#
# **Day 6: Royal and Bohemian Paris**
#
# * Visit the Luxembourg Gardens and explore the surrounding Latin Quarter
# * Explore the historic Saint-Chapelle, with its stunning stained glass windows
# * Visit the trendy Marais neighborhood, known
